# %%
import os,sys,glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import scipy.stats as st
import functions as fun
sourcedir = '/Volumes/My Passport/cmip5/cmip5'

# %%
basin = ['eais','wedd','amun','ross']
imods = ['AISM_VUB','BISI_LBL','CISM_NCA','FETI_VUB','GRIS_LSC','IMAU_VUB','ISSM_JPL','ISSM_UCI','MALI_LAN','PISM_AWI','PISM_DMI','PISM_PIK','PISM_VUW','PS3D_PSU','SICO_UHO','UA_UNN']
bm = 11.5

# %%
def append_TH(T0,T1,T2,T3,files,mask,vol):
    for fil in files:
        startyear = np.int(fil[-16:-12])
        print('Added TH',startyear)
        if startyear>2100: continue
        with xr.open_dataset(fil) as ds:
            th = ds['thetao'].values    
        tt = th[0::12,:,:]
        for f in range(1,12):
            ttnew = th[f::12,:,:]
            tt = tt[:ttnew.shape[0],:,:]+ttnew
        T0 = np.append(T0,np.nansum(tt*mask[0,:,:,:]*vol,axis=(1,2,3))/np.nansum(12.*mask[0,:,:,:]*vol))
        T1 = np.append(T1,np.nansum(tt*mask[1,:,:,:]*vol,axis=(1,2,3))/np.nansum(12.*mask[1,:,:,:]*vol))
        T2 = np.append(T2,np.nansum(tt*mask[2,:,:,:]*vol,axis=(1,2,3))/np.nansum(12.*mask[2,:,:,:]*vol))
        T3 = np.append(T3,np.nansum(tt*mask[3,:,:,:]*vol,axis=(1,2,3))/np.nansum(12.*mask[3,:,:,:]*vol))
    return T0,T1,T2,T3

# %%
def getgrid(model):
    #Get Antarctic mask
    with xr.open_dataset(f'../rawdata/Amaskdyn/{model}.nc') as ds:
        lon = ds['lon'].values
        lat = ds['lat'].values
        mask = ds['mask'].values
    return mask,lon,lat

def getvol(model):
    try:
        with xr.open_dataset(f'{sourcedir}/fx/volcello/{model}/r0i0p0/volcello_fx_{model}_historical_r0i0p0.nc') as ds:
            vol = ds['volcello'].values
    except:
        with xr.open_dataset(f'{sourcedir}/fx/areacello/{model}/r0i0p0/areacello_fx_{model}_historical_r0i0p0.nc') as ds:
            area = ds['areacello'].values
        files = glob.glob(f'{sourcedir}/{model}/r1i1p1/thetao_Omon_{model}_rcp85*')
        with xr.open_dataset(files[0]) as ds:
            lev = ds['lev_bnds'].values
        try:
            with xr.open_dataset(files[0]) as ds:
                dep = ds['depth'].values
            lev = lev[:,1]-lev[:,0]
            area2 = np.repeat(area[np.newaxis,:,:],len(lev),axis=0)
            lev2 = np.repeat(lev[:,np.newaxis],area.shape[0],axis=1)
            lev2 = np.repeat(lev2[:,:,np.newaxis],area.shape[1],axis=2)
            dep2 = np.repeat(dep[np.newaxis,:,:],len(lev),axis=0)
            vol = -dep2*area2*lev2
        except:
            lev = lev[:,1]-lev[:,0]
            area2 = np.repeat(area[np.newaxis,:,:],len(lev),axis=0)
            lev2 = np.repeat(lev[:,np.newaxis],area.shape[0],axis=1)
            lev2 = np.repeat(lev2[:,:,np.newaxis],area.shape[1],axis=2)
            vol = lev2*area2
    return vol

# %%
def gethist(model):
    #Get historical
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/thetao_Omon_{model}_historical*')
    Th0 = np.array([])
    Th1 = np.array([])
    Th2 = np.array([])
    Th3 = np.array([])
    Th0,Th1,Th2,Th3 = append_TH(Th0,Th1,Th2,Th3,files,mask,vol)
    print(model,'got hist')
    lastyear = np.int(files[-1][-9:-5])
    if lastyear>2005: 
        Th0 = Th0[:(2005-lastyear)]
        Th1 = Th1[:(2005-lastyear)]        
        Th2 = Th2[:(2005-lastyear)]
        Th3 = Th3[:(2005-lastyear)]
    firstyear = np.int(files[0][-16:-12])
    
    return Th0,Th1,Th2,Th3,firstyear

# %%
def getproj(model,scen,Th0,Th1,Th2,Th3,firstyear):
    
    #Get projected
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/thetao_Omon_{model}_{scen}*')
    T0,T1,T2,T3 = append_TH(Th0,Th1,Th2,Th3,files,mask,vol)
    print(model,scen,'got proj')
    years = np.arange(firstyear,firstyear+len(T0))
    
    TH = np.array([T0,T1,T2,T3])

    #Detrend
    for b in range(0,4):
        TH[b,:] = fun.detrend(TH[b,:],TH[b,:150],years)
        TH[b,:] = TH[b,:]-np.nanmean(TH[b,:150])
        
    #Extract 200 year time period 1900-2100
    TH = TH[:,np.logical_and(years>1900,years<2101)]
    years = years[np.logical_and(years>1900,years<2101)]
    
    return TH,years

# %%
def calcSLR(TH,years):
    SLRens = np.zeros((len(imods),TH.shape[0],TH.shape[1]))
    for i,imod in enumerate(imods):
        for b,bb in enumerate(range(1,5)):
            with open(f'../rawdata/Larmip2019-master/RFunctions/RF_{imod}_BM08_R{bb}.dat') as f:
                R = np.array([float(x) for x in f.readlines()])
            for t,tt in enumerate(years):
                if t==0: continue
                SLRens[i,b,t] = bm*100*np.sum(TH[b,:t][::-1]*R[:t])
            SLRens[i,b,:] = fun.detrend(SLRens[i,b,:],np.array([]),years)
    SLR = np.sum(SLRens,axis=(0,1))/len(imods)
    return SLR,years

# %%
mods = fun.models()
for model in mods:
    mask,lon,lat = getgrid(model)
    vol = getvol(model)
    Th0,Th1,Th2,Th3,firstyear = gethist(model)
    for scen in ['rcp45','rcp85']:
        TH,years = getproj(model,scen,Th0,Th1,Th2,Th3,firstyear)
        SLR,years = calcSLR(TH,years)
        #Save SLR
        fun.saveSLR(SLR,years,model,scen,'Adyn')
# Out:
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# Added TH 2010
# bcc-csm1-1 got hist
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# Added TH 2100
# Added TH 2110
# Added TH 2120
# Added TH 2130
# Added TH 2140
# Added TH 2150
# Added TH 2160
# bcc-csm1-1 rcp45 got proj
# rcp45 bcc-csm1-1 Saved  Adyn
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# Added TH 2100
# bcc-csm1-1 rcp85 got proj
# rcp85 bcc-csm1-1 Saved  Adyn
# Added TH 1850
# Added TH 1861
# Added TH 1871
# Added TH 1881
# Added TH 1891
# Added TH 1901
# Added TH 1911
# Added TH 1921
# Added TH 1931
# Added TH 1941
# Added TH 1951
# Added TH 1961
# Added TH 1971
# Added TH 1981
# Added TH 1991
# Added TH 2001
# CanESM2 got hist
# Added TH 2006
# Added TH 2011
# Added TH 2021
# Added TH 2031
# Added TH 2041
# Added TH 2051
# Added TH 2061
# Added TH 2071
# Added TH 2081
# Added TH 2091
# CanESM2 rcp45 got proj
# rcp45 CanESM2 Saved  Adyn
# Added TH 2006
# Added TH 2011
# Added TH 2021
# Added TH 2031
# Added TH 2041
# Added TH 2051
# Added TH 2061
# Added TH 2071
# Added TH 2081
# Added TH 2091
# CanESM2 rcp85 got proj
# rcp85 CanESM2 Saved  Adyn
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# CCSM4 got hist
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# CCSM4 rcp45 got proj
# rcp45 CCSM4 Saved  Adyn
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# CCSM4 rcp85 got proj
# rcp85 CCSM4 Saved  Adyn
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# CNRM-CM5 got hist
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# CNRM-CM5 rcp45 got proj
# rcp45 CNRM-CM5 Saved  Adyn
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# CNRM-CM5 rcp85 got proj
# rcp85 CNRM-CM5 Saved  Adyn
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# CSIRO-Mk3-6-0 got hist
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# CSIRO-Mk3-6-0 rcp45 got proj
# rcp45 CSIRO-Mk3-6-0 Saved  Adyn
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# CSIRO-Mk3-6-0 rcp85 got proj
# rcp85 CSIRO-Mk3-6-0 Saved  Adyn
# Added TH 1860
# Added TH 1865
# Added TH 1870
# Added TH 1875
# Added TH 1880
# Added TH 1885
# Added TH 1890
# Added TH 1895
# Added TH 1900
# Added TH 1905
# Added TH 1910
# Added TH 1915
# Added TH 1920
# Added TH 1925
# Added TH 1930
# Added TH 1935
# Added TH 1940
# Added TH 1945
# Added TH 1950
# Added TH 1955
# Added TH 1960
# Added TH 1965
# Added TH 1970
# Added TH 1975
# Added TH 1980
# Added TH 1985
# Added TH 1990
# Added TH 1995
# Added TH 2000
# Added TH 2005
# GFDL-CM3 got hist
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# GFDL-CM3 rcp45 got proj
# rcp45 GFDL-CM3 Saved  Adyn
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# GFDL-CM3 rcp85 got proj
# rcp85 GFDL-CM3 Saved  Adyn
# Added TH 1850
# Added TH 1876
# Added TH 1901
# Added TH 1926
# Added TH 1951
# Added TH 1976
# Added TH 2001
# GISS-E2-R got hist
# Added TH 2006
# Added TH 2026
# Added TH 2051
# Added TH 2076
# GISS-E2-R rcp45 got proj
# rcp45 GISS-E2-R Saved  Adyn
# Added TH 2006
# Added TH 2026
# Added TH 2051
# Added TH 2076
# GISS-E2-R rcp85 got proj
# rcp85 GISS-E2-R Saved  Adyn
# Added TH 1859
# Added TH 1869
# Added TH 1879
# Added TH 1889
# Added TH 1899
# Added TH 1909
# Added TH 1919
# Added TH 1929
# Added TH 1939
# Added TH 1949
# Added TH 1959
# Added TH 1969
# Added TH 1979
# Added TH 1989
# Added TH 1999
# HadGEM2-ES got hist
# Added TH 2005
# Added TH 2015
# Added TH 2025
# Added TH 2035
# Added TH 2045
# Added TH 2055
# Added TH 2065
# Added TH 2075
# Added TH 2085
# Added TH 2095
# Added TH 2099
# Added TH 2109
# Added TH 2119
# Added TH 2129
# Added TH 2139
# Added TH 2149
# Added TH 2159
# Added TH 2169
# Added TH 2179
# Added TH 2189
# Added TH 2199
# Added TH 2209
# HadGEM2-ES rcp45 got proj
# rcp45 HadGEM2-ES Saved  Adyn
# Added TH 2005
# Added TH 2015
# Added TH 2025
# Added TH 2035
# Added TH 2045
# Added TH 2055
# Added TH 2065
# Added TH 2075
# Added TH 2085
# Added TH 2095
# Added TH 2099
# HadGEM2-ES rcp85 got proj
# rcp85 HadGEM2-ES Saved  Adyn
# Added TH 1850
# Added TH 1855
# Added TH 1860
# Added TH 1865
# Added TH 1870
# Added TH 1875
# Added TH 1880
# Added TH 1885
# Added TH 1890
# Added TH 1895
# Added TH 1900
# Added TH 1905
# Added TH 1910
# Added TH 1915
# Added TH 1920
# Added TH 1925
# Added TH 1930
# Added TH 1935
# Added TH 1940
# Added TH 1945
# Added TH 1950
# Added TH 1955
# Added TH 1960
# Added TH 1965
# Added TH 1970
# Added TH 1975
# Added TH 1980
# Added TH 1985
# Added TH 1990
# Added TH 1995
# Added TH 2000
# Added TH 2005
# inmcm4 got hist
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# inmcm4 rcp45 got proj
# rcp45 inmcm4 Saved  Adyn
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# inmcm4 rcp85 got proj
# rcp85 inmcm4 Saved  Adyn
# Added TH 1850
# Added TH 1900
# Added TH 1950
# Added TH 2000
# IPSL-CM5A-LR got hist
# Added TH 2006
# Added TH 2056
# Added TH 2106
# Added TH 2156
# Added TH 2206
# Added TH 2256
# IPSL-CM5A-LR rcp45 got proj
# rcp45 IPSL-CM5A-LR Saved  Adyn
# Added TH 2006
# Added TH 2056
# IPSL-CM5A-LR rcp85 got proj
# rcp85 IPSL-CM5A-LR Saved  Adyn
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# MIROC-ESM got hist
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# MIROC-ESM rcp45 got proj
# rcp45 MIROC-ESM Saved  Adyn
# Added TH 2006
# Added TH 2016
# Added TH 2026
# Added TH 2036
# Added TH 2046
# Added TH 2056
# Added TH 2066
# Added TH 2076
# Added TH 2086
# Added TH 2096
# MIROC-ESM rcp85 got proj
# rcp85 MIROC-ESM Saved  Adyn
# Added TH 1850
# Added TH 1851
# Added TH 1852
# Added TH 1853
# Added TH 1854
# Added TH 1855
# Added TH 1856
# Added TH 1857
# Added TH 1858
# Added TH 1859
# Added TH 1860
# Added TH 1861
# Added TH 1862
# Added TH 1863
# Added TH 1864
# Added TH 1865
# Added TH 1866
# Added TH 1867
# Added TH 1868
# Added TH 1869
# Added TH 1870
# Added TH 1871
# Added TH 1872
# Added TH 1873
# Added TH 1874
# Added TH 1875
# Added TH 1876
# Added TH 1877
# Added TH 1878
# Added TH 1879
# Added TH 1880
# Added TH 1881
# Added TH 1882
# Added TH 1883
# Added TH 1884
# Added TH 1885
# Added TH 1886
# Added TH 1887
# Added TH 1888
# Added TH 1889
# Added TH 1890
# Added TH 1891
# Added TH 1892
# Added TH 1893
# Added TH 1894
# Added TH 1895
# Added TH 1896
# Added TH 1897
# Added TH 1898
# Added TH 1899
# Added TH 1900
# Added TH 1901
# Added TH 1902
# Added TH 1903
# Added TH 1904
# Added TH 1905
# Added TH 1906
# Added TH 1907
# Added TH 1908
# Added TH 1909
# Added TH 1910
# Added TH 1911
# Added TH 1912
# Added TH 1913
# Added TH 1914
# Added TH 1915
# Added TH 1916
# Added TH 1917
# Added TH 1918
# Added TH 1919
# Added TH 1920
# Added TH 1921
# Added TH 1922
# Added TH 1923
# Added TH 1924
# Added TH 1925
# Added TH 1926
# Added TH 1927
# Added TH 1928
# Added TH 1929
# Added TH 1930
# Added TH 1931
# Added TH 1932
# Added TH 1933
# Added TH 1934
# Added TH 1935
# Added TH 1936
# Added TH 1937
# Added TH 1938
# Added TH 1939
# Added TH 1940
# Added TH 1941
# Added TH 1942
# Added TH 1943
# Added TH 1944
# Added TH 1945
# Added TH 1946
# Added TH 1947
# Added TH 1948
# Added TH 1949
# Added TH 1950
# Added TH 1951
# Added TH 1952
# Added TH 1953
# Added TH 1954
# Added TH 1955
# Added TH 1956
# Added TH 1957
# Added TH 1958
# Added TH 1959
# Added TH 1960
# Added TH 1961
# Added TH 1962
# Added TH 1963
# Added TH 1964
# Added TH 1965
# Added TH 1966
# Added TH 1967
# Added TH 1968
# Added TH 1969
# Added TH 1970
# Added TH 1971
# Added TH 1972
# Added TH 1973
# Added TH 1974
# Added TH 1975
# Added TH 1976
# Added TH 1977
# Added TH 1978
# Added TH 1979
# Added TH 1980
# Added TH 1981
# Added TH 1982
# Added TH 1983
# Added TH 1984
# Added TH 1985
# Added TH 1986
# Added TH 1987
# Added TH 1988
# Added TH 1989
# Added TH 1990
# Added TH 1991
# Added TH 1992
# Added TH 1993
# Added TH 1994
# Added TH 1995
# Added TH 1996
# Added TH 1997
# Added TH 1998
# Added TH 1999
# Added TH 2000
# Added TH 2001
# Added TH 2002
# Added TH 2003
# Added TH 2004
# Added TH 2005
# Added TH 2006
# Added TH 2007
# Added TH 2008
# Added TH 2009
# Added TH 2010
# Added TH 2011
# Added TH 2012
# MIROC5 got hist
# Added TH 2006
# Added TH 2007
# Added TH 2008
# Added TH 2009
# Added TH 2010
# Added TH 2011
# Added TH 2012
# Added TH 2013
# Added TH 2014
# Added TH 2015
# Added TH 2016
# Added TH 2017
# Added TH 2018
# Added TH 2019
# Added TH 2020
# Added TH 2021
# Added TH 2022
# Added TH 2023
# Added TH 2024
# Added TH 2025
# Added TH 2026
# Added TH 2027
# Added TH 2028
# Added TH 2029
# Added TH 2030
# Added TH 2031
# Added TH 2032
# Added TH 2033
# Added TH 2034
# Added TH 2035
# Added TH 2036
# Added TH 2037
# Added TH 2038
# Added TH 2039
# Added TH 2040
# Added TH 2041
# Added TH 2042
# Added TH 2043
# Added TH 2044
# Added TH 2045
# Added TH 2046
# Added TH 2047
# Added TH 2048
# Added TH 2049
# Added TH 2050
# Added TH 2051
# Added TH 2052
# Added TH 2053
# Added TH 2054
# Added TH 2055
# Added TH 2056
# Added TH 2057
# Added TH 2058
# Added TH 2059
# Added TH 2060
# Added TH 2061
# Added TH 2062
# Added TH 2063
# Added TH 2064
# Added TH 2065
# Added TH 2066
# Added TH 2067
# Added TH 2068
# Added TH 2069
# Added TH 2070
# Added TH 2071
# Added TH 2072
# Added TH 2073
# Added TH 2074
# Added TH 2075
# Added TH 2076
# Added TH 2077
# Added TH 2078
# Added TH 2079
# Added TH 2080
# Added TH 2081
# Added TH 2082
# Added TH 2083
# Added TH 2084
# Added TH 2085
# Added TH 2086
# Added TH 2087
# Added TH 2088
# Added TH 2089
# Added TH 2090
# Added TH 2091
# Added TH 2092
# Added TH 2093
# Added TH 2094
# Added TH 2095
# Added TH 2096
# Added TH 2097
# Added TH 2098
# Added TH 2099
# Added TH 2100
# MIROC5 rcp45 got proj
# rcp45 MIROC5 Saved  Adyn
# Added TH 2006
# Added TH 2007
# Added TH 2008
# Added TH 2009
# Added TH 2010
# Added TH 2011
# Added TH 2012
# Added TH 2013
# Added TH 2014
# Added TH 2015
# Added TH 2016
# Added TH 2017
# Added TH 2018
# Added TH 2019
# Added TH 2020
# Added TH 2021
# Added TH 2022
# Added TH 2023
# Added TH 2024
# Added TH 2025
# Added TH 2026
# Added TH 2027
# Added TH 2028
# Added TH 2029
# Added TH 2030
# Added TH 2031
# Added TH 2032
# Added TH 2033
# Added TH 2034
# Added TH 2035
# Added TH 2036
# Added TH 2037
# Added TH 2038
# Added TH 2039
# Added TH 2040
# Added TH 2041
# Added TH 2042
# Added TH 2043
# Added TH 2044
# Added TH 2045
# Added TH 2046
# Added TH 2047
# Added TH 2048
# Added TH 2049
# Added TH 2050
# Added TH 2051
# Added TH 2052
# Added TH 2053
# Added TH 2054
# Added TH 2055
# Added TH 2056
# Added TH 2057
# Added TH 2058
# Added TH 2059
# Added TH 2060
# Added TH 2061
# Added TH 2062
# Added TH 2063
# Added TH 2064
# Added TH 2065
# Added TH 2066
# Added TH 2067
# Added TH 2068
# Added TH 2069
# Added TH 2070
# Added TH 2071
# Added TH 2072
# Added TH 2073
# Added TH 2074
# Added TH 2075
# Added TH 2076
# Added TH 2077
# Added TH 2078
# Added TH 2079
# Added TH 2080
# Added TH 2081
# Added TH 2082
# Added TH 2083
# Added TH 2084
# Added TH 2085
# Added TH 2086
# Added TH 2087
# Added TH 2088
# Added TH 2089
# Added TH 2090
# Added TH 2091
# Added TH 2092
# Added TH 2093
# Added TH 2094
# Added TH 2095
# Added TH 2096
# Added TH 2097
# Added TH 2098
# Added TH 2099
# Added TH 2100
# MIROC5 rcp85 got proj
# rcp85 MIROC5 Saved  Adyn
# Added TH 1850
# Added TH 1860
# Added TH 1870
# Added TH 1880
# Added TH 1890
# Added TH 1900
# Added TH 1910
# Added TH 1920
# Added TH 1930
# Added TH 1940
# Added TH 1950
# Added TH 1960
# Added TH 1970
# Added TH 1980
# Added TH 1990
# Added TH 2000
# MPI-ESM-LR got hist
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# Added TH 2101
# Added TH 2110
# Added TH 2120
# Added TH 2130
# Added TH 2140
# Added TH 2150
# Added TH 2160
# Added TH 2170
# Added TH 2180
# Added TH 2190
# Added TH 2200
# Added TH 2210
# Added TH 2220
# Added TH 2230
# Added TH 2240
# Added TH 2250
# Added TH 2260
# Added TH 2270
# Added TH 2280
# Added TH 2290
# MPI-ESM-LR rcp45 got proj
# rcp45 MPI-ESM-LR Saved  Adyn
# Added TH 2006
# Added TH 2010
# Added TH 2020
# Added TH 2030
# Added TH 2040
# Added TH 2050
# Added TH 2060
# Added TH 2070
# Added TH 2080
# Added TH 2090
# MPI-ESM-LR rcp85 got proj
# rcp85 MPI-ESM-LR Saved  Adyn
# Added TH 1850
# Added TH 1855
# Added TH 1860
# Added TH 1865
# Added TH 1870
# Added TH 1875
# Added TH 1880
# Added TH 1885
# Added TH 1890
# Added TH 1895
# Added TH 1900
# Added TH 1905
# Added TH 1910
# Added TH 1915
# Added TH 1920
# Added TH 1925
# Added TH 1930
# Added TH 1935
# Added TH 1940
# Added TH 1945
# Added TH 1950
# Added TH 1955
# Added TH 1960
# Added TH 1965
# Added TH 1970
# Added TH 1975
# Added TH 1980
# Added TH 1985
# Added TH 1990
# Added TH 1995
# Added TH 2000
# Added TH 2005
# MRI-CGCM3 got hist
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# MRI-CGCM3 rcp45 got proj
# rcp45 MRI-CGCM3 Saved  Adyn
# Added TH 2006
# Added TH 2011
# Added TH 2016
# Added TH 2021
# Added TH 2026
# Added TH 2031
# Added TH 2036
# Added TH 2041
# Added TH 2046
# Added TH 2051
# Added TH 2056
# Added TH 2061
# Added TH 2066
# Added TH 2071
# Added TH 2076
# Added TH 2081
# Added TH 2086
# Added TH 2091
# Added TH 2096
# MRI-CGCM3 rcp85 got proj
# rcp85 MRI-CGCM3 Saved  Adyn
# Added TH 1850
# Added TH 1854
# Added TH 1858
# Added TH 1862
# Added TH 1866
# Added TH 1870
# Added TH 1874
# Added TH 1878
# Added TH 1882
# Added TH 1886
# Added TH 1890
# Added TH 1894
# Added TH 1898
# Added TH 1902
# Added TH 1906
# Added TH 1910
# Added TH 1914
# Added TH 1918
# Added TH 1922
# Added TH 1926
# Added TH 1930
# Added TH 1934
# Added TH 1938
# Added TH 1942
# Added TH 1946
# Added TH 1950
# Added TH 1954
# Added TH 1958
# Added TH 1962
# Added TH 1966
# Added TH 1970
# Added TH 1974
# Added TH 1978
# Added TH 1982
# Added TH 1986
# Added TH 1990
# Added TH 1994
# Added TH 1998
# Added TH 2002
# NorESM1-M got hist
# Added TH 2006
# Added TH 2010
# Added TH 2014
# Added TH 2018
# Added TH 2022
# Added TH 2026
# Added TH 2030
# Added TH 2034
# Added TH 2038
# Added TH 2042
# Added TH 2046
# Added TH 2050
# Added TH 2054
# Added TH 2058
# Added TH 2062
# Added TH 2066
# Added TH 2070
# Added TH 2074
# Added TH 2078
# Added TH 2082
# Added TH 2086
# Added TH 2090
# Added TH 2094
# Added TH 2098
# Added TH 2101
# Added TH 2105
# Added TH 2109
# Added TH 2113
# Added TH 2117
# Added TH 2121
# Added TH 2125
# Added TH 2129
# Added TH 2133
# Added TH 2137
# Added TH 2141
# Added TH 2145
# Added TH 2149
# Added TH 2153
# Added TH 2157
# Added TH 2161
# Added TH 2165
# Added TH 2169
# Added TH 2173
# Added TH 2177
# Added TH 2181
# Added TH 2185
# Added TH 2189
# Added TH 2193
# Added TH 2197
# Added TH 2201
# Added TH 2205
# Added TH 2209
# Added TH 2213
# Added TH 2217
# Added TH 2221
# Added TH 2225
# Added TH 2229
# Added TH 2233
# Added TH 2237
# Added TH 2241
# Added TH 2245
# Added TH 2249
# Added TH 2253
# Added TH 2257
# Added TH 2261
# Added TH 2265
# Added TH 2269
# Added TH 2273
# Added TH 2277
# Added TH 2281
# Added TH 2285
# Added TH 2289
# Added TH 2293
# Added TH 2297
# NorESM1-M rcp45 got proj
# rcp45 NorESM1-M Saved  Adyn
# Added TH 2006
# Added TH 2010
# Added TH 2014
# Added TH 2018
# Added TH 2022
# Added TH 2026
# Added TH 2030
# Added TH 2034
# Added TH 2038
# Added TH 2042
# Added TH 2046
# Added TH 2050
# Added TH 2054
# Added TH 2058
# Added TH 2062
# Added TH 2066
# Added TH 2070
# Added TH 2074
# Added TH 2078
# Added TH 2082
# Added TH 2086
# Added TH 2090
# Added TH 2094
# Added TH 2098
# NorESM1-M rcp85 got proj
# rcp85 NorESM1-M Saved  Adyn
