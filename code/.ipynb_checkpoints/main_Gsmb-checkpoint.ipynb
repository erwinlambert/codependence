# %%
import os,sys,glob
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import scipy.stats as st
import functions as fun
sourcedir = '/Volumes/My Passport/cmip5/cmip5'

# %%
def append_SF(SF,files,mask2,area):
    if len(files)==0:
        print('nopi SF')
        return SF
        
    for fil in files:
        startyear = np.int(fil[-16:-12])
        if startyear>2100: continue
        print('Added SF',startyear)
        with xr.open_dataset(fil) as ds:
            sf = ds['prsn'].values
        ss = sf[0::12,:,:]
        for f in range(1,12):
            ssnew = sf[f::12,:,:]
            ss = ss[:ssnew.shape[0],:,:]+ssnew
        SF = np.append(SF,np.nansum(ss*mask2*area/12.,axis=(1,2)))
    return SF

# %%
def append_TA(TA,files,mask,area):
    if len(files)==0:
        print('nopi SF')
        return TA
    
    for fil in files:
        startyear = np.int(fil[-16:-12])
        if startyear>2100: continue
        print('Added TA',startyear)
        with xr.open_dataset(fil) as ds:
            plev = ds['plev'].values
            idx  = np.argmin((plev-60000)**2)
            ta   = ds['ta'][:,idx,:,:].values
        startmonth=int(fil[-12:-10])
        if startmonth==12:
            junidx = 6
        elif startmonth ==1:
            junidx = 5
        tajun = ta[junidx::12,:,:]
        tajul = ta[junidx+1::12,:,:]
        taaug = ta[junidx+2::12,:,:]
        tajja = (30.*tajun+31.*tajul+31.*taaug)/92.
        weight = mask*area
        if weight.shape[0]>tajja.shape[1]:
            weight = (weight[1:,:]+weight[:-1,:])/2.
        TA = np.append(TA,np.nansum(tajja*weight,axis=(1,2))/np.nansum(weight))
    return TA

# %%
def getSF(model,scen,mask2,area):
    
    #Get historical snowfall
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/prsn_Amon_{model}_historical*')
    SF = np.array([])
    SF = append_SF(SF,files,mask2,area)
    lastyear = np.int(files[-1][-9:-5])
    if lastyear>2005: SF = SF[:(2005-lastyear)]
    firstyear = np.int(files[0][-16:-12])

    #Future period
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/prsn_Amon_{model}_{scen}*')
    SF = append_SF(SF,files,mask2,area)
    years = np.arange(firstyear,firstyear+len(SF))

    #picontrol
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/prsn_Amon_{model}_piControl*')  
    SF_pi = np.array([])
    SF_pi = append_SF(SF_pi,files,mask2,area)
    
    #Detrend
    SF = fun.detrend(SF,SF_pi,years)
    
    #Convert to GT/yr
    SF = SF*3.154e-5*1.6
    
    print(scen,model,'Got SF')
    return SF,years

# %%
def getTA(model,scen,mask,area):
    #Get historical temperature
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/ta_Amon_{model}_historical*')
    TA = np.array([])
    TA = append_TA(TA,files,mask,area)
    lastyear = np.int(files[-1][-9:-5])
    if lastyear>2005: TA = TA[:(2005-lastyear)]
    firstyear = np.int(files[0][-16:-12])
    
    #Get projected temp
    files = glob.glob(f'{sourcedir}/{model}/r1i1p1/ta_Amon_{model}_{scen}*')
    TA = append_TA(TA,files,mask,area)
    years = np.arange(firstyear,firstyear+len(TA))
   
    #No piControl for TA as models show no trends
    
    #Reference
    TA = fun.detrend(TA,np.array([]),years)    
    
    print(scen,model,'Got TA')
    return TA,years

# %%
def Gsmb(model,scen):

    #Get Greenland mask
    with xr.open_dataset(f'../rawdata/Gmask/{model}.nc') as ds:
        lon = ds['lon'].values
        lat = ds['lat'].values
        mask = ds['mask'].values
        mask2 = ds['mask2'].values

    #Get surface area
    with xr.open_dataset(f'{sourcedir}/fx/areacella/{model}/r0i0p0/areacella_fx_{model}_historical_r0i0p0.nc') as ds:
        area = ds['areacella'].values

    #Get snowfall change
    SF,years1 = getSF(model,scen,mask2,area)

    #Get temperature increase
    TA,years2 = getTA(model,scen,mask,area)

    #Ensure overlapping periods
    if len(years1)>len(years2):
        SF = SF[np.in1d(years1,years2)]
        years = years2
    elif len(years2)>len(years1):
        TA = TA[np.in1d(years2,years1)]
        years = years1
    else:
        years = years1

    #Convert to sea-level change
    MW  = 84.2*TA + 2.4*TA**2. + 1.6*TA**3.
    SMB = SF-MW
    SLR = -np.cumsum(SMB)*2.8e-4 #in cm
    SLR = fun.detrend(SLR,np.array([]),years)
    
    plt.plot(years,SLR)
    
    #Save SLR
    fun.saveSLR(SLR,years,model,scen,'Gsmb')

# %%
mods = fun.models()
for scen in ['rcp45','rcp85']:
    for model in mods:
        Gsmb(model,scen)
# Out:
# Added SF 1850
# Added SF 2006
# Added SF 2100
# Added SF 1
# rcp45 bcc-csm1-1 Got SF
# Added TA 1850
# Added TA 2006
# Added TA 2100
# Added TA 2200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b9eb18ba33fb> in <module>
#       2 for scen in ['rcp45','rcp85']:
#       3     for model in mods:
# ----> 4         Gsmb(model,scen)
#
# <ipython-input-7-1dbce51e9c6d> in Gsmb(model, scen)
#      16
#      17     #Get temperature increase
# ---> 18     TA,years2 = getTA(model,scen,mask,area)
#      19
#      20     #Ensure overlapping periods
#
# <ipython-input-6-30052a7c437a> in getTA(model, scen, mask, area)
#      10     #Get projected temp
#      11     files = glob.glob(f'{sourcedir}/{model}/r1i1p1/ta_Amon_{model}_{scen}*')
# ---> 12     TA = append_TA(TA,files,mask,area)
#      13     years = np.arange(firstyear,firstyear+len(TA))
#      14
#
# <ipython-input-4-e3d256bca9fe> in append_TA(TA, files, mask, area)
#       7         startyear = np.int(fil[-16:-12])
#       8         print('Added TA',startyear)
# ----> 9         with xr.open_dataset(fil) as ds:
#      10             plev = ds['plev'].values
#      11             idx  = np.argmin((plev-60000)**2)
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime)
#     533
#     534     with close_on_error(store):
# --> 535         ds = maybe_decode_store(store)
#     536
#     537     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/backends/api.py in maybe_decode_store(store, lock)
#     448             decode_coords=decode_coords,
#     449             drop_variables=drop_variables,
# --> 450             use_cftime=use_cftime,
#     451         )
#     452
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime)
#     585         use_cftime=use_cftime,
#     586     )
# --> 587     ds = Dataset(vars, attrs=attrs)
#     588     ds = ds.set_coords(coord_names.union(extra_coords).intersection(vars))
#     589     ds._file_obj = file_obj
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/dataset.py in __init__(self, data_vars, coords, attrs, compat)
#     533
#     534         variables, coord_names, dims, indexes = merge_data_and_coords(
# --> 535             data_vars, coords, compat=compat
#     536         )
#     537
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/merge.py in merge_data_and_coords(data, coords, compat, join)
#     465     indexes = dict(_extract_indexes_from_coords(coords))
#     466     return merge_core(
# --> 467         objects, compat, join, explicit_coords=explicit_coords, indexes=indexes
#     468     )
#     469
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/merge.py in merge_core(objects, compat, join, priority_arg, explicit_coords, indexes, fill_value)
#     550         coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     551     )
# --> 552     collected = collect_variables_and_indexes(aligned)
#     553
#     554     prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/merge.py in collect_variables_and_indexes(list_of_mappings)
#     275                 append_all(coords, indexes)
#     276
# --> 277             variable = as_variable(variable, name=name)
#     278             if variable.dims == (name,):
#     279                 variable = variable.to_index_variable()
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/variable.py in as_variable(obj, name)
#     143                 "dimensions." % (name, obj.dims)
#     144             )
# --> 145         obj = obj.to_index_variable()
#     146
#     147     return obj
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/variable.py in to_index_variable(self)
#     463         """Return this variable as an xarray.IndexVariable"""
#     464         return IndexVariable(
# --> 465             self.dims, self._data, self._attrs, encoding=self._encoding, fastpath=True
#     466         )
#     467
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/variable.py in __init__(self, dims, data, attrs, encoding, fastpath)
#    2029         # Unlike in Variable, always eagerly load values into memory
#    2030         if not isinstance(self._data, PandasIndexAdapter):
# -> 2031             self._data = PandasIndexAdapter(self._data)
#    2032
#    2033     def __dask_tokenize__(self):
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/indexing.py in __init__(self, array, dtype)
#    1329
#    1330     def __init__(self, array: Any, dtype: DTypeLike = None):
# -> 1331         self.array = utils.safe_cast_to_index(array)
#    1332         if dtype is None:
#    1333             if isinstance(array, pd.PeriodIndex):
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/utils.py in safe_cast_to_index(array)
#     101         if hasattr(array, "dtype") and array.dtype.kind == "O":
#     102             kwargs["dtype"] = object
# --> 103         index = pd.Index(np.asarray(array), **kwargs)
#     104     return _maybe_cast_to_cftimeindex(index)
#     105
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     545     def __array__(self, dtype=None):
#     546         array = as_indexable(self.array)
# --> 547         return np.asarray(array[self.key], dtype=None)
#     548
#     549     def transpose(self, order):
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/coding/variables.py in __array__(self, dtype)
#      70
#      71     def __array__(self, dtype=None):
# ---> 72         return self.func(self.array)
#      73
#      74     def __repr__(self):
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     148     cftime.num2date
#     149     """
# --> 150     num_dates = np.asarray(num_dates)
#     151     flat_num_dates = num_dates.ravel()
#     152     if calendar is None:
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/indexing.py in __array__(self, dtype)
#     545     def __array__(self, dtype=None):
#     546         array = as_indexable(self.array)
# --> 547         return np.asarray(array[self.key], dtype=None)
#     548
#     549     def transpose(self, order):
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __getitem__(self, key)
#      70     def __getitem__(self, key):
#      71         return indexing.explicit_indexing_adapter(
# ---> 72             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem
#      73         )
#      74
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     825     """
#     826     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 827     result = raw_indexing_method(raw_key.tuple)
#     828     if numpy_indices.tuple:
#     829         # index the loaded np.ndarray
#
# ~/miniconda2/envs/codep/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _getitem(self, key)
#      82             with self.datastore.lock:
#      83                 original_array = self.get_array(needs_lock=False)
# ---> 84                 array = getitem(original_array, key)
#      85         except IndexError:
#      86             # Catch IndexError in netCDF4 and return a more informative
#
# KeyboardInterrupt:
